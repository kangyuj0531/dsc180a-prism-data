# %%
import pandas as pd

inflows = pd.read_parquet('/uss/hdsi-prismdata/q1-ucsd-inflows.pqt')
outflows = pd.read_parquet('/uss/hdsi-prismdata/q1-ucsd-outflows.pqt')

# %%
import re
import pandas as pd
from collections import Counter

# Global counter to track removed items
removed_counter = Counter()

# Common junk words or tokens to remove
JUNK_WORDS = {
    # system / channel tokens
    "checkcard","debit","credit","withdrawal","purchase","payment","auth","pos","atm",
    "authorized","self_transfer","external_transfer","recurring","accountfees","creditcardpayment",
    "ref","txn","trxn","bill","card","paymentauth","point","of","sale",
    # web-ish
    "www","com","org","net","http","https","amazoncom","amzn",
    # common short junk and state codes (tweak if you want to keep)
    "crd","pur","md","va","ca","ny","nv","oh","fl","tx"
}

def clean_memo(text):
    """Cleans transaction memo strings and counts removed patterns."""
    global removed_counter

    if pd.isna(text):
        return ""
    
    s = str(text)

    # Normalize separators
    s = s.replace("*", " ").replace("/", " ").replace("\\", " ").replace("-", " ").replace(".", " ")

    # --- Track and Remove System Keywords ---
    sys_keywords = re.findall(
        r'\b(?:CHECKCARD|DEBIT|CREDIT|WITHDRAWAL|PURCHASE|PAYMENT|AUTH|POS|ATM|SELF_TRANSFER|EXTERNAL_TRANSFER|RECURRING|AUTHORIZED|ACCOUNTFEES|CREDITCARDPAYMENT|REF|TXN|TRXN)\b',
        s, flags=re.IGNORECASE)
    removed_counter.update([kw.lower() for kw in sys_keywords])
    s = re.sub(
        r'\b(?:CHECKCARD|DEBIT|CREDIT|WITHDRAWAL|PURCHASE|PAYMENT|AUTH|POS|ATM|SELF_TRANSFER|EXTERNAL_TRANSFER|RECURRING|AUTHORIZED|ACCOUNTFEES|CREDITCARDPAYMENT|REF|TXN|TRXN)\b',
        ' ', s, flags=re.IGNORECASE)

    # --- Track & Remove Visa/Check phrases ---
    visa_patterns = re.findall(r'\b(?:visa|mastercard|check\s*card|visa\s*check|visa\s*debit)\b', s, flags=re.IGNORECASE)
    removed_counter.update([kw.lower() for kw in visa_patterns])
    s = re.sub(r'\b(?:visa|mastercard|check\s*card|visa\s*check|visa\s*debit)\b', ' ', s, flags=re.IGNORECASE)

    # --- Track & Remove VSA PMT patterns ---
    vsa_patterns = re.findall(r'\b(?:vsa\s*pmt|vsa|pmt)\b', s, flags=re.IGNORECASE)
    removed_counter.update([kw.lower() for kw in vsa_patterns])
    s = re.sub(r'\b(?:vsa\s*pmt|vsa|pmt)\b', ' ', s, flags=re.IGNORECASE)

    # --- Track & Remove https/www tokens ---
    https_tokens = re.findall(r'\bhttps?www\w*\b', s, flags=re.IGNORECASE)
    removed_counter.update(["httpswww" for _ in https_tokens])
    s = re.sub(r'\bhttps?www\w*\b', ' ', s, flags=re.IGNORECASE)

    # --- Track & Remove xxx patterns ---
    xxx_count = len(re.findall(r'\w*x{2,}\w*', s, flags=re.IGNORECASE))
    removed_counter["xxx_patterns"] += xxx_count
    s = re.sub(r'\w*x{2,}\w*', ' ', s, flags=re.IGNORECASE)

    # --- Track & Remove mixed alphanumeric tokens ---
    mixed_count = len(re.findall(r'\b(?=\w*[A-Za-z])(?=\w*\d)\w+\b', s))
    removed_counter["mixed_alphanum"] += mixed_count
    s = re.sub(r'\b(?=\w*[A-Za-z])(?=\w*\d)\w+\b', ' ', s)

    # --- Track & Remove numeric data (dates, codes, etc.) ---
    num_count = len(re.findall(r'\b\d+\b', s))
    removed_counter["numbers"] += num_count
    s = re.sub(r'\b\d{2}/\d{2}\b', ' ', s)
    s = re.sub(r'\b\d{4}\b', ' ', s)
    s = re.sub(r'\b\d+\b', ' ', s)

    # --- Remove punctuation & normalize ---
    s = re.sub(r'[^A-Za-z\s]', ' ', s)
    s = re.sub(r'\s{2,}', ' ', s).strip().lower()

    # --- Token filtering ---
    tokens = []
    for t in s.split():
        if len(t) <= 2:  # single or two-letter token
            removed_counter["short_tokens"] += 1
            continue
        if t in JUNK_WORDS:
            removed_counter["junk_words"] += 1
            continue
        tokens.append(t)

    return " ".join(tokens)

# %%
removed_counter.clear()  # Reset counter

outflows['memo_clean'] = outflows['memo'].apply(clean_memo)

# %%
outflows[['memo', 'memo_clean']].sample(50)
# Out:
#                                                       memo  \
# 2313105  PURCHASE AUTHORIZED ON 07/21 SQ *NUKAY JEWELRY...
# 2263102    XXXX PUR KROGER 672 ANNA IL (12/31/20 23:40:45)
# 209471                                              Amazon
# 252043                                   EXTERNAL_TRANSFER
# 1127241                                           Circle K
# 2251877  PURCHASE AUTHORIZED ON 07/12 PRICELN*TOWN AND ...
# 2144192                                  EXTERNAL_TRANSFER
# 792620   PURCHASE AUTHORIZED ON 09/22 TARGET XXXX PHOEN...
# 294400                                           Taco Bell
# 1225891                                         McDonald's
# 328857                                          McDonald's
# 421463              GRACE HAULING / MOUS : POS Transaction
# 513103                                                LOAN
# 1258745                                      SELF_TRANSFER
# 650325                                                LOAN
# 613701                                   EXTERNAL_TRANSFER
# 421153   BLUESTONE MID R XXXX MID RIVERS / MALL DRSAINT...
# 1151463                               Venice Food Wine INC
# 2296000  PURCHASE AUTHORIZED ON 01/03 BAKERS ONLINE 128...
# 1399827                                               LOAN
# 150847                                            7-Eleven
# 2396462                                               LOAN
# 816384           CHECK CARD PURCHASE TST* BOULEVARD BURGER
# 970968                                       SELF_TRANSFER
# 603649                                   EXTERNAL_TRANSFER
# 1935849  PURCHASE AUTHORIZED ON 06/17 MCDONALD'S MXXXX ...
# 2545294                                CREDIT_CARD_PAYMENT
# 2209077  CHECKCARD XXXX AMZN Mktp US*261J Amzn.com/bill...
# 1058594                                  EXTERNAL_TRANSFER
# 416460                                   EXTERNAL_TRANSFER
# 651592                                       UNCATEGORIZED
# 11524                                         ACCOUNT_FEES
# 796720                                  ESSENTIAL_SERVICES
# 1404530  POS Debit - Visa Check Card XXXX - MATINI(MART...
# 866482                                  HEALTHCARE_MEDICAL
# 5275                                          ACCOUNT_FEES
# 2389704  Withdrawal POS #XXXXXXXXXXXX POS DOLLAR GENERA...
# 808778                                   EXTERNAL_TRANSFER
# 1194919                                               LOAN
# 2002402               POS Signature Purchase -  STOP &amp;
# 1956478                                           ATM_CASH
# 409511                                    HOME_IMPROVEMENT
# 55597                                                 LOAN
# 759439                                   EXTERNAL_TRANSFER
# 2346861  CHECKCARD XXXX DUNKIN #XXXXXX Q35 SPARTANBURG ...
# 1457047                                         McDonald's
# 367273                                          AUTOMOTIVE
# 1973932                                             Amazon
# 408498                                          AUTOMOTIVE
# 1029850                                         AUTOMOTIVE
#
#                                                 memo_clean
# 2313105                              nukay jewelry hialeah
# 2263102                                        kroger anna
# 209471                                              amazon
# 252043
# 1127241                                             circle
# 2251877                                   priceln town and
# 2144192
# 792620                                      target phoenix
# 294400                                           taco bell
# 1225891                                           mcdonald
# 328857                                            mcdonald
# 421463                      grace hauling mous transaction
# 513103                                                loan
# 1258745
# 650325                                                loan
# 613701
# 421153   bluestone mid mid rivers mall drsaint peters m...
# 1151463                               venice food wine inc
# 2296000                                  bakers online olo
# 1399827                                               loan
# 150847                                              eleven
# 2396462                                               loan
# 816384                                tst boulevard burger
# 970968
# 603649
# 1935849                              mcdonald cutler ridge
# 2545294
# 2209077                                        mktp billwa
# 1058594
# 416460
# 651592                                       uncategorized
# 11524                                         account fees
# 796720                                  essential services
# 1404530                         matini martini chilgok gun
# 866482                                  healthcare medical
# 5275                                          account fees
# 2389704                             dollar general belleoh
# 808778
# 1194919                                               loan
# 2002402                                 signature stop amp
# 1956478                                               cash
# 409511                                    home improvement
# 55597                                                 loan
# 759439
# 2346861                                 dunkin spartanburg
# 1457047                                           mcdonald
# 367273                                          automotive
# 1973932                                             amazon
# 408498                                          automotive
# 1029850                                         automotive

# %%
import matplotlib.pyplot as plt

removed_df = pd.DataFrame(removed_counter.most_common(), columns=["pattern_removed", "count"])

plt.figure(figsize=(10,6))
plt.barh(removed_df.head(15)["pattern_removed"], removed_df.head(15)["count"], color="tomato")
plt.gca().invert_yaxis()
plt.title("Most Frequently Removed Tokens or Patterns")
plt.xlabel("Count Removed")
plt.ylabel("Removed Pattern")
plt.show()

# %%
outflows.loc[224163, ['memo', 'memo_clean']]
# Out:
# memo          CHECKCARD XXXX WNYC WQXR NJPR NYPR RAD XXX-XXX...
# memo_clean                              wnyc wqxr njpr nypr rad
# Name: 224163, dtype: object
